# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import os
import datetime
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.layers import Flatten
from keras.layers import Dropout
from keras.layers import RepeatVector
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

print("Num GPUs Available: ", len(tf.config.list_physical_devices("GPU")))
# fix random seed for reproducibility
tf.random.set_seed(8)
# Out:
# Num GPUs Available:  1

# %%
# Hyperparameter
TRAIN_TEST_RATIO = 0.67
TIME_STEP = 8
MODEL_TYPE = "CNN_LSTM_DNN2"
EPOCH_SIZE = 1000
BATCH_SIZE = 4
FEATURE_NUMBER = 3
MODEL_JSON = {}
def to_string():
    print_list = [
        f"Time step: {TIME_STEP}",
        f"Ratio: {TRAIN_TEST_RATIO}",
        f"Model type: {MODEL_TYPE}",
        f"Epoch size: {EPOCH_SIZE}",
        f"Batch size: {BATCH_SIZE}",
        f"Model json: {MODEL_JSON}",
    ]
    return "\n".join(print_list)

# %%
dataframe = pd.read_excel('Data/Data_for_ML_TT-DB1.xlsx', sheet_name="Sheet1", header=1, usecols=[0,1,2])
dataset = dataframe.values
# dataset = np.reshape(dataset, (-1, 3))

#Preprocessing
# dataset[np.isnan(dataset)] = 0

dataset = dataset.astype('float64')
# plt.clf()
plt.figure(figsize=(10,6))
plt.plot(dataset[:,1], color="green")
plt.twinx()
plt.plot(dataset[:,2])
plt.rcParams.update({'font.size': 10})
plt.show()

# %% [markdown]
# Normalize the dataset, when working with sigmoid or tanh function as activation function, normalize data to range 0, 1

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * TRAIN_TEST_RATIO)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 331 164

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1, y_col=0):
	dataX, dataY = [], []
	for i in range(len(dataset)-look_back-1):
		a = dataset[i:(i+look_back), :]
		dataX.append(a)
		dataY.append(dataset[i + look_back, y_col])
	return np.array(dataX), np.array(dataY)

# %%
pca = PCA(n_components = 1)
FEATURE_NUMBER = 1
print(train.shape)
train_x = pca.fit_transform(train)
test_x = pca.transform(test)
print(train_x.shape)
print(test_x.shape)
# Out:
# (331, 3)
# (331, 1)
# (164, 1)

# %%
# reshape into X=t and Y=t+1
# train_x, train_y = create_dataset(train, TIME_STEP, 2)
# test_x, test_y = create_dataset(test, TIME_STEP, 2)
train_x, _ = create_dataset(train_x, TIME_STEP)
test_x, _ = create_dataset(test_x, TIME_STEP)
_, train_y = create_dataset(train, TIME_STEP,2)
_, test_y = create_dataset(test, TIME_STEP,2)
print(train_x.shape)
print(train_y.shape)
print(test_x.shape)
print(test_y.shape)
# Out:
# (322, 8, 1)
# (322,)
# (155, 8, 1)
# (155,)

# %%
# reshape input to be [samples, time steps, features]
train_x = np.reshape(train_x, (train_x.shape[0], TIME_STEP, FEATURE_NUMBER))
test_x = np.reshape(test_x, (test_x.shape[0], TIME_STEP, FEATURE_NUMBER))
print(train_x.shape)
print(test_x.shape)
# Out:
# (322, 8, 1)
# (155, 8, 1)

# %%
# create and fit the LSTM network
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', 
                                min_delta=0.00001, 
                                # patience=int(EPOCH_SIZE*0.05), 
                                patience=int(20), 
                                verbose=0, 
                                mode='auto', 
                                baseline=None, 
                                restore_best_weights=True)
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
model = Sequential()
if MODEL_TYPE == "LSTM":
    model.add(LSTM(32, input_shape=(TIME_STEP, FEATURE_NUMBER), return_sequences=True))
    model.add(LSTM(32, input_shape=(TIME_STEP, FEATURE_NUMBER)))
    model.add(Dense(1))
elif MODEL_TYPE == "CNN":
    model.add(Conv1D(32, (3), activation='relu', input_shape=(TIME_STEP,FEATURE_NUMBER)))
    # model.add(layers.MaxPooling1D((2)))
    model.add(Conv1D(64, (3), activation='relu'))
    # model.add(layers.MaxPooling1D((2)))
    model.add(Conv1D(64, (3), activation='relu'))
    model.add(MaxPooling1D((2)))
    model.add(Flatten())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
elif MODEL_TYPE == "CNN_LSTM":
    model.add(
        Conv1D(6, (3), activation="relu", input_shape=(TIME_STEP, 1))
    )
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1)))
    model.add(Dense(1))
elif MODEL_TYPE == "CNN_LSTM_DNN":
    model.add(
        Conv1D(64, (5), activation="relu", input_shape=(TIME_STEP, FEATURE_NUMBER))
    )
    model.add(
        LSTM(
            32, "relu", input_shape=(TIME_STEP, FEATURE_NUMBER), return_sequences=True
        )
    )
    model.add(LSTM(32, "relu", input_shape=(TIME_STEP, FEATURE_NUMBER)))
    model.add(Dense(16))
    model.add(Dense(8))
    model.add(Dense(1))
elif MODEL_TYPE == "CNN_LSTM_DNN2":
    model.add(
        Conv1D(128, (2), activation="relu", input_shape=(TIME_STEP, FEATURE_NUMBER))
    )
    model.add(
        LSTM(
            200,"relu", input_shape=(TIME_STEP, FEATURE_NUMBER), return_sequences=True
        )
    )
    model.add(LSTM(100,"relu", input_shape=(TIME_STEP, FEATURE_NUMBER)))
    model.add(Dense(16))
    model.add(Dense(8))
    model.add(Dense(1))
elif MODEL_TYPE == "CNN_LSTM_DNN3":
    model.add(
        Conv1D(128, (2), activation="relu", input_shape=(TIME_STEP, FEATURE_NUMBER))
    )
    model.add(
        LSTM(
            32,"relu", input_shape=(TIME_STEP, FEATURE_NUMBER), return_sequences=True
        )
    )
    model.add(LSTM(32,"relu", input_shape=(TIME_STEP, FEATURE_NUMBER)))
    model.add(Dense(64))
    model.add(Dense(32))
    model.add(Dense(1))
elif MODEL_TYPE == "LSTM_DNN":
    model.add(
        LSTM(
            32, "relu", input_shape=(TIME_STEP, FEATURE_NUMBER), return_sequences=True
        )
    )
    model.add(Dropout(0.2))
    model.add(
        LSTM(
            32, "relu", input_shape=(TIME_STEP, FEATURE_NUMBER), return_sequences=True
        )
    )
    model.add(LSTM(32, "relu", input_shape=(TIME_STEP, FEATURE_NUMBER)))
    model.add(Dense(16))
    model.add(Dense(8))
    model.add(Dense(1))
elif MODEL_TYPE == "LSTM_DNN2":
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1)))
    model.add(Dense(16))
    model.add(Dense(1))
elif MODEL_TYPE == "LSTM_DNN3":
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1), return_sequences=True))
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1)))
    model.add(Dense(32))
    model.add(Dense(1))
elif MODEL_TYPE == "LSTM_DNN4":
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1)))
    model.add(Dense(32))
    model.add(Dense(1))
elif MODEL_TYPE == "LSTM_DNN5":
    model.add(LSTM(300, "relu", input_shape=(TIME_STEP, 1)))
    model.add(Dense(1))
model.summary()
MODEL_JSON = model.to_json()
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(train_x, train_y, epochs=EPOCH_SIZE, batch_size=BATCH_SIZE, verbose=2, callbacks=[early_stopping, tensorboard_callback])
# %tensorboard --logdir logs/fit
# Out:
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_34 (LSTM)              (None, 300)               362400
#
#  dense_48 (Dense)            (None, 16)                4816
#
#  dense_49 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 367,233
# Trainable params: 367,233
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 81/81 - 3s - loss: 0.0587 - 3s/epoch - 40ms/step
# Epoch 2/1000
# 81/81 - 2s - loss: 0.0252 - 2s/epoch - 27ms/step
# Epoch 3/1000
# 81/81 - 2s - loss: 0.0230 - 2s/epoch - 23ms/step
# Epoch 4/1000
# 81/81 - 2s - loss: 0.0258 - 2s/epoch - 26ms/step
# Epoch 5/1000
# 81/81 - 2s - loss: 0.0226 - 2s/epoch - 31ms/step
# Epoch 6/1000
# 81/81 - 2s - loss: 0.0213 - 2s/epoch - 27ms/step
# Epoch 7/1000
# 81/81 - 2s - loss: 0.0239 - 2s/epoch - 24ms/step
# Epoch 8/1000
# 81/81 - 2s - loss: 0.0217 - 2s/epoch - 21ms/step
# Epoch 9/1000
# 81/81 - 2s - loss: 0.0226 - 2s/epoch - 22ms/step
# Epoch 10/1000
# 81/81 - 2s - loss: 0.0213 - 2s/epoch - 21ms/step
# Epoch 11/1000
# 81/81 - 2s - loss: 0.0220 - 2s/epoch - 22ms/step
# Epoch 12/1000
# 81/81 - 2s - loss: 0.0202 - 2s/epoch - 22ms/step
# Epoch 13/1000
# 81/81 - 2s - loss: 0.0211 - 2s/epoch - 22ms/step
# Epoch 14/1000
# 81/81 - 2s - loss: 0.0197 - 2s/epoch - 23ms/step
# Epoch 15/1000
# 81/81 - 2s - loss: 0.0202 - 2s/epoch - 22ms/step
# Epoch 16/1000
# 81/81 - 2s - loss: 0.0196 - 2s/epoch - 23ms/step
# Epoch 17/1000
# 81/81 - 2s - loss: 0.0194 - 2s/epoch - 20ms/step
# Epoch 18/1000
# 81/81 - 2s - loss: 0.0191 - 2s/epoch - 21ms/step
# Epoch 19/1000
# 81/81 - 2s - loss: 0.0188 - 2s/epoch - 21ms/step
# Epoch 20/1000
# 81/81 - 2s - loss: 0.0202 - 2s/epoch - 20ms/step
# Epoch 21/1000
# 81/81 - 2s - loss: 0.0192 - 2s/epoch - 21ms/step
# Epoch 22/1000
# 81/81 - 2s - loss: 0.0189 - 2s/epoch - 20ms/step
# Epoch 23/1000
# 81/81 - 2s - loss: 0.0186 - 2s/epoch - 24ms/step
# Epoch 24/1000
# 81/81 - 2s - loss: 0.0184 - 2s/epoch - 22ms/step
# Epoch 25/1000
# 81/81 - 2s - loss: 0.0181 - 2s/epoch - 22ms/step
# Epoch 26/1000
# 81/81 - 2s - loss: 0.0181 - 2s/epoch - 20ms/step
# Epoch 27/1000
# 81/81 - 2s - loss: 0.0182 - 2s/epoch - 20ms/step
# Epoch 28/1000
# 81/81 - 2s - loss: 0.0202 - 2s/epoch - 20ms/step
# Epoch 29/1000
# 81/81 - 2s - loss: 0.0180 - 2s/epoch - 19ms/step
# Epoch 30/1000
# 81/81 - 2s - loss: 0.0180 - 2s/epoch - 20ms/step
# Epoch 31/1000
# 81/81 - 2s - loss: 0.0176 - 2s/epoch - 20ms/step
# Epoch 32/1000
# 81/81 - 2s - loss: 0.0179 - 2s/epoch - 22ms/step
# Epoch 33/1000
# 81/81 - 2s - loss: 0.0174 - 2s/epoch - 25ms/step
# Epoch 34/1000
# 81/81 - 2s - loss: 0.0172 - 2s/epoch - 23ms/step
# Epoch 35/1000
# 81/81 - 2s - loss: 0.0176 - 2s/epoch - 23ms/step
# Epoch 36/1000
# 81/81 - 2s - loss: 0.0165 - 2s/epoch - 19ms/step
# Epoch 37/1000
# 81/81 - 2s - loss: 0.0171 - 2s/epoch - 20ms/step
# Epoch 38/1000
# 81/81 - 2s - loss: 0.0166 - 2s/epoch - 21ms/step
# Epoch 39/1000
# 81/81 - 2s - loss: 0.0170 - 2s/epoch - 21ms/step
# Epoch 40/1000
# 81/81 - 2s - loss: 0.0167 - 2s/epoch - 22ms/step
# Epoch 41/1000
# 81/81 - 2s - loss: 0.0171 - 2s/epoch - 30ms/step
# Epoch 42/1000
# 81/81 - 2s - loss: 0.0162 - 2s/epoch - 29ms/step
# Epoch 43/1000
# 81/81 - 2s - loss: 0.0167 - 2s/epoch - 29ms/step
# Epoch 44/1000
# 81/81 - 2s - loss: 0.0167 - 2s/epoch - 28ms/step
# Epoch 45/1000
# 81/81 - 2s - loss: 0.0171 - 2s/epoch - 27ms/step
# Epoch 46/1000
# 81/81 - 2s - loss: 0.0163 - 2s/epoch - 25ms/step
# Epoch 47/1000
# 81/81 - 2s - loss: 0.0173 - 2s/epoch - 25ms/step
# Epoch 48/1000
# 81/81 - 2s - loss: 0.0168 - 2s/epoch - 21ms/step
# Epoch 49/1000
# 81/81 - 2s - loss: 0.0161 - 2s/epoch - 23ms/step
# Epoch 50/1000
# 81/81 - 2s - loss: 0.0157 - 2s/epoch - 21ms/step
# Epoch 51/1000
# 81/81 - 2s - loss: 0.0156 - 2s/epoch - 24ms/step
# Epoch 52/1000
# 81/81 - 2s - loss: 0.0159 - 2s/epoch - 25ms/step
# Epoch 53/1000
# 81/81 - 2s - loss: 0.0154 - 2s/epoch - 24ms/step
# Epoch 54/1000
# 81/81 - 2s - loss: 0.0164 - 2s/epoch - 22ms/step
# Epoch 55/1000
# 81/81 - 2s - loss: 0.0160 - 2s/epoch - 20ms/step
# Epoch 56/1000
# 81/81 - 2s - loss: 0.0156 - 2s/epoch - 24ms/step
# Epoch 57/1000
# 81/81 - 2s - loss: 0.0153 - 2s/epoch - 23ms/step
# Epoch 58/1000
# 81/81 - 2s - loss: 0.0162 - 2s/epoch - 26ms/step
# Epoch 59/1000
# 81/81 - 2s - loss: 0.0162 - 2s/epoch - 20ms/step
# Epoch 60/1000
# 81/81 - 2s - loss: 0.0152 - 2s/epoch - 21ms/step
# Epoch 61/1000
# 81/81 - 2s - loss: 0.0149 - 2s/epoch - 21ms/step
# Epoch 62/1000
# 81/81 - 2s - loss: 0.0150 - 2s/epoch - 22ms/step
# Epoch 63/1000
# 81/81 - 2s - loss: 0.0170 - 2s/epoch - 22ms/step
# Epoch 64/1000
# 81/81 - 2s - loss: 0.0151 - 2s/epoch - 21ms/step
# Epoch 65/1000
# 81/81 - 2s - loss: 0.0152 - 2s/epoch - 20ms/step
# Epoch 66/1000
# 81/81 - 2s - loss: 0.0152 - 2s/epoch - 19ms/step
# Epoch 67/1000
# 81/81 - 2s - loss: 0.0151 - 2s/epoch - 20ms/step
# Epoch 68/1000
# 81/81 - 2s - loss: 0.0155 - 2s/epoch - 21ms/step
# Epoch 69/1000
# 81/81 - 2s - loss: 0.0154 - 2s/epoch - 20ms/step
# Epoch 70/1000
# 81/81 - 2s - loss: 0.0154 - 2s/epoch - 20ms/step
# Epoch 71/1000
# 81/81 - 2s - loss: 0.0150 - 2s/epoch - 21ms/step
# Epoch 72/1000
# 81/81 - 2s - loss: 0.0159 - 2s/epoch - 21ms/step
# Epoch 73/1000
# 81/81 - 2s - loss: 0.0147 - 2s/epoch - 22ms/step
# Epoch 74/1000
# 81/81 - 2s - loss: 0.0146 - 2s/epoch - 23ms/step
# Epoch 75/1000
# 81/81 - 2s - loss: 0.0148 - 2s/epoch - 20ms/step
# Epoch 76/1000
# 81/81 - 2s - loss: 0.0149 - 2s/epoch - 21ms/step
# Epoch 77/1000
# 81/81 - 2s - loss: 0.0149 - 2s/epoch - 19ms/step
# Epoch 78/1000
# 81/81 - 2s - loss: 0.0150 - 2s/epoch - 20ms/step
# Epoch 79/1000
# 81/81 - 2s - loss: 0.0145 - 2s/epoch - 21ms/step
# Epoch 80/1000
# 81/81 - 2s - loss: 0.0146 - 2s/epoch - 19ms/step
# Epoch 81/1000
# 81/81 - 2s - loss: 0.0142 - 2s/epoch - 20ms/step
# Epoch 82/1000
# 81/81 - 2s - loss: 0.0144 - 2s/epoch - 19ms/step
# Epoch 83/1000
# 81/81 - 2s - loss: 0.0145 - 2s/epoch - 19ms/step
# Epoch 84/1000
# 81/81 - 2s - loss: 0.0147 - 2s/epoch - 20ms/step
# Epoch 85/1000
# 81/81 - 2s - loss: 0.0143 - 2s/epoch - 21ms/step
# Epoch 86/1000
# 81/81 - 2s - loss: 0.0144 - 2s/epoch - 19ms/step
# Epoch 87/1000
# 81/81 - 2s - loss: 0.0142 - 2s/epoch - 23ms/step
# Epoch 88/1000
# 81/81 - 2s - loss: 0.0142 - 2s/epoch - 29ms/step
# Epoch 89/1000
# 81/81 - 2s - loss: 0.0144 - 2s/epoch - 25ms/step
# Epoch 90/1000
# 81/81 - 2s - loss: 0.0137 - 2s/epoch - 26ms/step
# Epoch 91/1000
# 81/81 - 2s - loss: 0.0134 - 2s/epoch - 29ms/step
# Epoch 92/1000
# 81/81 - 2s - loss: 0.0137 - 2s/epoch - 28ms/step
# Epoch 93/1000
# 81/81 - 2s - loss: 0.0142 - 2s/epoch - 31ms/step
# Epoch 94/1000
# 81/81 - 2s - loss: 0.0137 - 2s/epoch - 28ms/step
# Epoch 95/1000
# 81/81 - 2s - loss: 0.0140 - 2s/epoch - 25ms/step
# Epoch 96/1000
# 81/81 - 2s - loss: 0.0138 - 2s/epoch - 22ms/step
# Epoch 97/1000
# 81/81 - 2s - loss: 0.0139 - 2s/epoch - 21ms/step
# Epoch 98/1000
# 81/81 - 2s - loss: 0.0142 - 2s/epoch - 21ms/step
# Epoch 99/1000
# 81/81 - 2s - loss: 0.0133 - 2s/epoch - 25ms/step
# Epoch 100/1000
# 81/81 - 2s - loss: 0.0133 - 2s/epoch - 24ms/step
# Epoch 101/1000
# 81/81 - 2s - loss: 0.0144 - 2s/epoch - 24ms/step
# Epoch 102/1000
# 81/81 - 2s - loss: 0.0130 - 2s/epoch - 28ms/step
# Epoch 103/1000
# 81/81 - 2s - loss: 0.0140 - 2s/epoch - 26ms/step
# Epoch 104/1000
# 81/81 - 2s - loss: 0.0136 - 2s/epoch - 25ms/step
# Epoch 105/1000
# 81/81 - 2s - loss: 0.0136 - 2s/epoch - 22ms/step
# Epoch 106/1000
# 81/81 - 2s - loss: 0.0134 - 2s/epoch - 23ms/step
# Epoch 107/1000
# 81/81 - 2s - loss: 0.0131 - 2s/epoch - 23ms/step
# Epoch 108/1000
# 81/81 - 2s - loss: 0.0133 - 2s/epoch - 22ms/step
# Epoch 109/1000
# 81/81 - 2s - loss: 0.0127 - 2s/epoch - 25ms/step
# Epoch 110/1000
# 81/81 - 2s - loss: 0.0129 - 2s/epoch - 24ms/step
# Epoch 111/1000
# 81/81 - 2s - loss: 0.0128 - 2s/epoch - 26ms/step
# Epoch 112/1000
# 81/81 - 2s - loss: 0.0128 - 2s/epoch - 25ms/step
# Epoch 113/1000
# 81/81 - 2s - loss: 0.0127 - 2s/epoch - 25ms/step
# Epoch 114/1000
# 81/81 - 2s - loss: 0.0128 - 2s/epoch - 22ms/step
# Epoch 115/1000
# 81/81 - 2s - loss: 0.0127 - 2s/epoch - 25ms/step
# Epoch 116/1000
# 81/81 - 2s - loss: 0.0130 - 2s/epoch - 25ms/step
# Epoch 117/1000
# 81/81 - 2s - loss: 0.0128 - 2s/epoch - 22ms/step
# Epoch 118/1000
# 81/81 - 2s - loss: 0.0124 - 2s/epoch - 23ms/step
# Epoch 119/1000
# 81/81 - 2s - loss: 0.0123 - 2s/epoch - 22ms/step
# Epoch 120/1000
# 81/81 - 2s - loss: 0.0132 - 2s/epoch - 23ms/step
# Epoch 121/1000
# 81/81 - 2s - loss: 0.0122 - 2s/epoch - 23ms/step
# Epoch 122/1000
# 81/81 - 2s - loss: 0.0125 - 2s/epoch - 24ms/step
# Epoch 123/1000
# 81/81 - 2s - loss: 0.0124 - 2s/epoch - 24ms/step
# Epoch 124/1000
# 81/81 - 2s - loss: 0.0122 - 2s/epoch - 23ms/step
# Epoch 125/1000
# 81/81 - 2s - loss: 0.0127 - 2s/epoch - 26ms/step
# Epoch 126/1000
# 81/81 - 2s - loss: 0.0120 - 2s/epoch - 26ms/step
# Epoch 127/1000
# 81/81 - 2s - loss: 0.0117 - 2s/epoch - 24ms/step
# Epoch 128/1000
# 81/81 - 2s - loss: 0.0112 - 2s/epoch - 23ms/step
# Epoch 129/1000
# 81/81 - 2s - loss: 0.0116 - 2s/epoch - 22ms/step
# Epoch 130/1000
# 81/81 - 2s - loss: 0.0117 - 2s/epoch - 22ms/step
# Epoch 131/1000
# 81/81 - 2s - loss: 0.0119 - 2s/epoch - 22ms/step
# Epoch 132/1000
# 81/81 - 2s - loss: 0.0113 - 2s/epoch - 24ms/step
# Epoch 133/1000
# 81/81 - 2s - loss: 0.0117 - 2s/epoch - 22ms/step
# Epoch 134/1000
# 81/81 - 2s - loss: 0.0122 - 2s/epoch - 25ms/step
# Epoch 135/1000
# 81/81 - 2s - loss: 0.0115 - 2s/epoch - 29ms/step
# Epoch 136/1000
# 81/81 - 2s - loss: 0.0117 - 2s/epoch - 27ms/step
# Epoch 137/1000
# 81/81 - 2s - loss: 0.0115 - 2s/epoch - 22ms/step
# Epoch 138/1000
# 81/81 - 2s - loss: 0.0114 - 2s/epoch - 24ms/step
# Epoch 139/1000
# 81/81 - 2s - loss: 0.0141 - 2s/epoch - 21ms/step
# Epoch 140/1000
# 81/81 - 2s - loss: 0.0116 - 2s/epoch - 20ms/step
# Epoch 141/1000
# 81/81 - 2s - loss: 0.0111 - 2s/epoch - 20ms/step
# Epoch 142/1000
# 81/81 - 2s - loss: 0.0115 - 2s/epoch - 20ms/step
# Epoch 143/1000
# 81/81 - 2s - loss: 0.0117 - 2s/epoch - 20ms/step
# Epoch 144/1000
# 81/81 - 2s - loss: 0.0117 - 2s/epoch - 20ms/step
# Epoch 145/1000
# 81/81 - 2s - loss: 0.0113 - 2s/epoch - 20ms/step
# Epoch 146/1000
# 81/81 - 2s - loss: 0.0111 - 2s/epoch - 19ms/step
# Epoch 147/1000
# 81/81 - 2s - loss: 0.0113 - 2s/epoch - 20ms/step
# Epoch 148/1000
# 81/81 - 2s - loss: 0.0107 - 2s/epoch - 22ms/step
# Epoch 149/1000
# 81/81 - 2s - loss: 0.0111 - 2s/epoch - 21ms/step
# Epoch 150/1000
# 81/81 - 2s - loss: 0.0118 - 2s/epoch - 22ms/step
# Epoch 151/1000
# 81/81 - 2s - loss: 0.0110 - 2s/epoch - 25ms/step
# Epoch 152/1000
# 81/81 - 2s - loss: 0.0107 - 2s/epoch - 25ms/step
# Epoch 153/1000
# 81/81 - 2s - loss: 0.0108 - 2s/epoch - 24ms/step
# Epoch 154/1000
# 81/81 - 2s - loss: 0.0102 - 2s/epoch - 21ms/step
# Epoch 155/1000
# 81/81 - 2s - loss: 0.0103 - 2s/epoch - 22ms/step
# Epoch 156/1000
# 81/81 - 2s - loss: 0.0103 - 2s/epoch - 22ms/step
# Epoch 157/1000
# 81/81 - 2s - loss: 0.0110 - 2s/epoch - 25ms/step
# Epoch 158/1000
# 81/81 - 2s - loss: 0.0108 - 2s/epoch - 21ms/step
# Epoch 159/1000
# 81/81 - 2s - loss: 0.0101 - 2s/epoch - 23ms/step
# Epoch 160/1000
# 81/81 - 2s - loss: 0.0105 - 2s/epoch - 23ms/step
# Epoch 161/1000
# 81/81 - 2s - loss: 0.0107 - 2s/epoch - 21ms/step
# Epoch 162/1000
# 81/81 - 2s - loss: 0.0105 - 2s/epoch - 21ms/step
# Epoch 163/1000
# 81/81 - 2s - loss: 0.0100 - 2s/epoch - 20ms/step
# Epoch 164/1000
# 81/81 - 2s - loss: 0.0105 - 2s/epoch - 19ms/step
# Epoch 165/1000
# 81/81 - 2s - loss: 0.0102 - 2s/epoch - 20ms/step
# Epoch 166/1000
# 81/81 - 2s - loss: 0.0111 - 2s/epoch - 22ms/step
# Epoch 167/1000
# 81/81 - 2s - loss: 0.0104 - 2s/epoch - 19ms/step
# Epoch 168/1000
# 81/81 - 2s - loss: 0.0096 - 2s/epoch - 23ms/step
# Epoch 169/1000
# 81/81 - 2s - loss: 0.0099 - 2s/epoch - 25ms/step
# Epoch 170/1000
# 81/81 - 2s - loss: 0.0101 - 2s/epoch - 27ms/step
# Epoch 171/1000
# 81/81 - 2s - loss: 0.0096 - 2s/epoch - 23ms/step
# Epoch 172/1000
# 81/81 - 2s - loss: 0.0103 - 2s/epoch - 21ms/step
# Epoch 173/1000
# 81/81 - 2s - loss: 0.0102 - 2s/epoch - 19ms/step
# Epoch 174/1000
# 81/81 - 2s - loss: 0.0104 - 2s/epoch - 20ms/step
# Epoch 175/1000
# 81/81 - 2s - loss: 0.0100 - 2s/epoch - 23ms/step
# Epoch 176/1000
# 81/81 - 2s - loss: 0.0095 - 2s/epoch - 23ms/step
# Epoch 177/1000
# 81/81 - 2s - loss: 0.0099 - 2s/epoch - 21ms/step
# Epoch 178/1000
# 81/81 - 2s - loss: 0.0091 - 2s/epoch - 22ms/step
# Epoch 179/1000
# 81/81 - 2s - loss: 0.0090 - 2s/epoch - 21ms/step
# Epoch 180/1000
# 81/81 - 2s - loss: 0.0093 - 2s/epoch - 21ms/step
# Epoch 181/1000
# 81/81 - 2s - loss: 0.0102 - 2s/epoch - 21ms/step
# Epoch 182/1000
# 81/81 - 2s - loss: 0.0095 - 2s/epoch - 22ms/step
# Epoch 183/1000
# 81/81 - 2s - loss: 0.0090 - 2s/epoch - 20ms/step
# Epoch 184/1000
# 81/81 - 2s - loss: 0.0090 - 2s/epoch - 20ms/step
# Epoch 185/1000
# 81/81 - 2s - loss: 0.0090 - 2s/epoch - 20ms/step
# Epoch 186/1000
# 81/81 - 2s - loss: 0.0091 - 2s/epoch - 19ms/step
# Epoch 187/1000
# 81/81 - 2s - loss: 0.0100 - 2s/epoch - 20ms/step
# Epoch 188/1000
# 81/81 - 2s - loss: 0.0097 - 2s/epoch - 21ms/step
# Epoch 189/1000
# 81/81 - 2s - loss: 0.0086 - 2s/epoch - 20ms/step
# Epoch 190/1000
# 81/81 - 2s - loss: 0.0084 - 2s/epoch - 19ms/step
# Epoch 191/1000
# 81/81 - 2s - loss: 0.0084 - 2s/epoch - 20ms/step
# Epoch 192/1000
# 81/81 - 2s - loss: 0.0081 - 2s/epoch - 20ms/step
# Epoch 193/1000
# 81/81 - 2s - loss: 0.0085 - 2s/epoch - 19ms/step
# Epoch 194/1000
# 81/81 - 2s - loss: 0.0084 - 2s/epoch - 19ms/step
# Epoch 195/1000
# 81/81 - 2s - loss: 0.0082 - 2s/epoch - 19ms/step
# Epoch 196/1000
# 81/81 - 2s - loss: 0.0078 - 2s/epoch - 21ms/step
# Epoch 197/1000
# 81/81 - 2s - loss: 0.0081 - 2s/epoch - 22ms/step
# Epoch 198/1000
# 81/81 - 2s - loss: 0.0083 - 2s/epoch - 19ms/step
# Epoch 199/1000
# 81/81 - 2s - loss: 0.0082 - 2s/epoch - 19ms/step
# Epoch 200/1000
# 81/81 - 2s - loss: 0.0093 - 2s/epoch - 19ms/step
# Epoch 201/1000
# 81/81 - 2s - loss: 0.0086 - 2s/epoch - 21ms/step
# Epoch 202/1000
# 81/81 - 2s - loss: 0.0078 - 2s/epoch - 22ms/step
# Epoch 203/1000
# 81/81 - 2s - loss: 0.0078 - 2s/epoch - 20ms/step
# Epoch 204/1000
# 81/81 - 2s - loss: 0.0077 - 2s/epoch - 20ms/step
# Epoch 205/1000
# 81/81 - 2s - loss: 0.0086 - 2s/epoch - 20ms/step
# Epoch 206/1000
# 81/81 - 2s - loss: 0.0081 - 2s/epoch - 20ms/step
# Epoch 207/1000
# 81/81 - 2s - loss: 0.0076 - 2s/epoch - 21ms/step
# Epoch 208/1000
# 81/81 - 2s - loss: 0.0073 - 2s/epoch - 23ms/step
# Epoch 209/1000
# 81/81 - 2s - loss: 0.0080 - 2s/epoch - 20ms/step
# Epoch 210/1000
# 81/81 - 2s - loss: 0.0070 - 2s/epoch - 21ms/step
# Epoch 211/1000
# 81/81 - 2s - loss: 0.0070 - 2s/epoch - 20ms/step
# Epoch 212/1000
# 81/81 - 2s - loss: 0.0076 - 2s/epoch - 19ms/step
# Epoch 213/1000
# 81/81 - 2s - loss: 0.0074 - 2s/epoch - 19ms/step
# Epoch 214/1000
# 81/81 - 2s - loss: 0.0069 - 2s/epoch - 19ms/step
# Epoch 215/1000
# 81/81 - 2s - loss: 0.0074 - 2s/epoch - 19ms/step
# Epoch 216/1000
# 81/81 - 2s - loss: 0.0072 - 2s/epoch - 19ms/step
# Epoch 217/1000
# 81/81 - 2s - loss: 0.0072 - 2s/epoch - 20ms/step
# Epoch 218/1000
# 81/81 - 2s - loss: 0.0068 - 2s/epoch - 19ms/step
# Epoch 219/1000
# 81/81 - 2s - loss: 0.0081 - 2s/epoch - 19ms/step
# Epoch 220/1000
# 81/81 - 2s - loss: 0.0090 - 2s/epoch - 20ms/step
# Epoch 221/1000
# 81/81 - 2s - loss: 0.0080 - 2s/epoch - 20ms/step
# Epoch 222/1000
# 81/81 - 2s - loss: 0.0068 - 2s/epoch - 20ms/step
# Epoch 223/1000
# 81/81 - 2s - loss: 0.0066 - 2s/epoch - 20ms/step
# Epoch 224/1000
# 81/81 - 2s - loss: 0.0078 - 2s/epoch - 20ms/step
# Epoch 225/1000
# 81/81 - 2s - loss: 0.0071 - 2s/epoch - 20ms/step
# Epoch 226/1000
# 81/81 - 2s - loss: 0.0076 - 2s/epoch - 20ms/step
# Epoch 227/1000
# 81/81 - 2s - loss: 0.0077 - 2s/epoch - 20ms/step
# Epoch 228/1000
# 81/81 - 2s - loss: 0.0095 - 2s/epoch - 20ms/step
# Epoch 229/1000
# 81/81 - 2s - loss: 0.0073 - 2s/epoch - 20ms/step
# Epoch 230/1000
# 81/81 - 2s - loss: 0.0067 - 2s/epoch - 19ms/step
# Epoch 231/1000
# 81/81 - 2s - loss: 0.0065 - 2s/epoch - 19ms/step
# Epoch 232/1000
# 81/81 - 2s - loss: 0.0060 - 2s/epoch - 19ms/step
# Epoch 233/1000
# 81/81 - 2s - loss: 0.0069 - 2s/epoch - 20ms/step
# Epoch 234/1000
# 81/81 - 2s - loss: 0.0082 - 2s/epoch - 19ms/step
# Epoch 235/1000
# 81/81 - 2s - loss: 0.0065 - 2s/epoch - 20ms/step
# Epoch 236/1000
# 81/81 - 2s - loss: 0.0077 - 2s/epoch - 23ms/step
# Epoch 237/1000
# 81/81 - 2s - loss: 0.0063 - 2s/epoch - 20ms/step
# Epoch 238/1000
# 81/81 - 2s - loss: 0.0063 - 2s/epoch - 19ms/step
# Epoch 239/1000
# 81/81 - 2s - loss: 0.0061 - 2s/epoch - 20ms/step
# Epoch 240/1000
# 81/81 - 2s - loss: 0.0074 - 2s/epoch - 20ms/step
# Epoch 241/1000
# 81/81 - 2s - loss: 0.0071 - 2s/epoch - 20ms/step
# Epoch 242/1000
# 81/81 - 2s - loss: 0.0063 - 2s/epoch - 20ms/step
# Epoch 243/1000
# 81/81 - 2s - loss: 0.0060 - 2s/epoch - 20ms/step
# Epoch 244/1000
# 81/81 - 2s - loss: 0.0054 - 2s/epoch - 19ms/step
# Epoch 245/1000
# 81/81 - 2s - loss: 0.0068 - 2s/epoch - 19ms/step
# Epoch 246/1000
# 81/81 - 2s - loss: 0.0066 - 2s/epoch - 19ms/step
# Epoch 247/1000
# 81/81 - 2s - loss: 0.0073 - 2s/epoch - 19ms/step
# Epoch 248/1000
# 81/81 - 2s - loss: 0.0078 - 2s/epoch - 20ms/step
# Epoch 249/1000
# 81/81 - 2s - loss: 0.0066 - 2s/epoch - 20ms/step
# Epoch 250/1000
# 81/81 - 2s - loss: 0.0054 - 2s/epoch - 21ms/step
# Epoch 251/1000
# 81/81 - 2s - loss: 0.0051 - 2s/epoch - 24ms/step
# Epoch 252/1000
# 81/81 - 2s - loss: 0.0051 - 2s/epoch - 19ms/step
# Epoch 253/1000
# 81/81 - 2s - loss: 0.0066 - 2s/epoch - 20ms/step
# Epoch 254/1000
# 81/81 - 2s - loss: 0.0064 - 2s/epoch - 19ms/step
# Epoch 255/1000
# 81/81 - 2s - loss: 0.0065 - 2s/epoch - 19ms/step
# Epoch 256/1000
# 81/81 - 2s - loss: 0.0063 - 2s/epoch - 21ms/step
# Epoch 257/1000
# 81/81 - 2s - loss: 0.0056 - 2s/epoch - 20ms/step
# Epoch 258/1000
# 81/81 - 2s - loss: 0.0051 - 2s/epoch - 19ms/step
# Epoch 259/1000
# 81/81 - 2s - loss: 0.0051 - 2s/epoch - 20ms/step
# Epoch 260/1000
# 81/81 - 2s - loss: 0.0062 - 2s/epoch - 20ms/step
# Epoch 261/1000
# 81/81 - 2s - loss: 0.0061 - 2s/epoch - 19ms/step
# Epoch 262/1000
# 81/81 - 2s - loss: 0.0060 - 2s/epoch - 20ms/step
# Epoch 263/1000
# 81/81 - 2s - loss: 0.0058 - 2s/epoch - 20ms/step
# Epoch 264/1000
# 81/81 - 2s - loss: 0.0064 - 2s/epoch - 19ms/step
# Epoch 265/1000
# 81/81 - 2s - loss: 0.0072 - 2s/epoch - 20ms/step
# Epoch 266/1000
# 81/81 - 2s - loss: 0.0052 - 2s/epoch - 19ms/step
# Epoch 267/1000
# 81/81 - 2s - loss: 0.0059 - 2s/epoch - 19ms/step
# Epoch 268/1000
# 81/81 - 2s - loss: 0.0066 - 2s/epoch - 20ms/step
# Epoch 269/1000
# 81/81 - 2s - loss: 0.0066 - 2s/epoch - 20ms/step
# Epoch 270/1000
# 81/81 - 2s - loss: 0.0059 - 2s/epoch - 19ms/step
# Epoch 271/1000
# 81/81 - 2s - loss: 0.0053 - 2s/epoch - 20ms/step
# Epoch 272/1000
# 81/81 - 2s - loss: 0.0048 - 2s/epoch - 19ms/step
# Epoch 273/1000
# 81/81 - 2s - loss: 0.0051 - 2s/epoch - 19ms/step
# Epoch 274/1000
# 81/81 - 2s - loss: 0.0057 - 2s/epoch - 20ms/step
# Epoch 275/1000
# 81/81 - 2s - loss: 0.0062 - 2s/epoch - 22ms/step
# Epoch 276/1000
# 81/81 - 2s - loss: 0.0059 - 2s/epoch - 19ms/step
# Epoch 277/1000
# 81/81 - 2s - loss: 0.0053 - 2s/epoch - 19ms/step
# Epoch 278/1000
# 81/81 - 2s - loss: 0.0052 - 2s/epoch - 20ms/step
# Epoch 279/1000
# 81/81 - 2s - loss: 0.0049 - 2s/epoch - 19ms/step
# Epoch 280/1000
# 81/81 - 2s - loss: 0.0049 - 2s/epoch - 20ms/step
# Epoch 281/1000
# 81/81 - 2s - loss: 0.0050 - 2s/epoch - 20ms/step
# Epoch 282/1000
# 81/81 - 1s - loss: 0.0051 - 1s/epoch - 18ms/step
# Epoch 283/1000
# 81/81 - 2s - loss: 0.0054 - 2s/epoch - 20ms/step
# Epoch 284/1000
# 81/81 - 2s - loss: 0.0057 - 2s/epoch - 19ms/step
# Epoch 285/1000
# 81/81 - 2s - loss: 0.0064 - 2s/epoch - 19ms/step
# Epoch 286/1000
# 81/81 - 2s - loss: 0.0060 - 2s/epoch - 20ms/step
# Epoch 287/1000
# 81/81 - 2s - loss: 0.0047 - 2s/epoch - 19ms/step
# Epoch 288/1000
# 81/81 - 2s - loss: 0.0053 - 2s/epoch - 19ms/step
# Epoch 289/1000
# 81/81 - 2s - loss: 0.0050 - 2s/epoch - 20ms/step
# Epoch 290/1000
# 81/81 - 2s - loss: 0.0052 - 2s/epoch - 20ms/step
# Epoch 291/1000
# 81/81 - 2s - loss: 0.0053 - 2s/epoch - 21ms/step
# Epoch 292/1000
# 81/81 - 2s - loss: 0.0054 - 2s/epoch - 21ms/step
# Epoch 293/1000
# 81/81 - 2s - loss: 0.0043 - 2s/epoch - 20ms/step
# Epoch 294/1000
# 81/81 - 2s - loss: 0.0041 - 2s/epoch - 20ms/step
# Epoch 295/1000
# 81/81 - 2s - loss: 0.0044 - 2s/epoch - 19ms/step
# Epoch 296/1000
# 81/81 - 2s - loss: 0.0054 - 2s/epoch - 19ms/step
# Epoch 297/1000
# 81/81 - 2s - loss: 0.0055 - 2s/epoch - 19ms/step
# Epoch 298/1000
# 81/81 - 2s - loss: 0.0052 - 2s/epoch - 20ms/step
# Epoch 299/1000
# 81/81 - 2s - loss: 0.0047 - 2s/epoch - 19ms/step
# Epoch 300/1000
# 81/81 - 2s - loss: 0.0055 - 2s/epoch - 19ms/step
# Epoch 301/1000
# 81/81 - 2s - loss: 0.0063 - 2s/epoch - 19ms/step
# Epoch 302/1000
# 81/81 - 2s - loss: 0.0068 - 2s/epoch - 19ms/step
# Epoch 303/1000
# 81/81 - 2s - loss: 0.0057 - 2s/epoch - 19ms/step
# Epoch 304/1000
# 81/81 - 2s - loss: 0.0050 - 2s/epoch - 19ms/step
# Epoch 305/1000
# 81/81 - 2s - loss: 0.0050 - 2s/epoch - 19ms/step
# Epoch 306/1000
# 81/81 - 2s - loss: 0.0046 - 2s/epoch - 20ms/step
# Epoch 307/1000
# 81/81 - 2s - loss: 0.0046 - 2s/epoch - 19ms/step
# Epoch 308/1000
# 81/81 - 2s - loss: 0.0045 - 2s/epoch - 19ms/step
# Epoch 309/1000
# 81/81 - 2s - loss: 0.0043 - 2s/epoch - 20ms/step
# Epoch 310/1000
# 81/81 - 2s - loss: 0.0045 - 2s/epoch - 19ms/step
# Epoch 311/1000
# 81/81 - 2s - loss: 0.0042 - 2s/epoch - 21ms/step
# Epoch 312/1000
# 81/81 - 2s - loss: 0.0044 - 2s/epoch - 20ms/step
# Epoch 313/1000
# 81/81 - 1s - loss: 0.0044 - 1s/epoch - 18ms/step
# Epoch 314/1000
# 81/81 - 2s - loss: 0.0052 - 2s/epoch - 21ms/step
# UsageError: Line magic function `%tensorboard` not found.

# %%
# save model
version = 0
for dir in os.scandir(f"./Model3/"):
    if dir.is_dir():
        version = int(dir.name) if int(dir.name) > version else version
version += 1
model.save(f"./Model3/{version}")
# Out:
# INFO:tensorflow:Assets written to: ./Model3/14\assets
# INFO:tensorflow:Assets written to: ./Model3/14\assets

# %%
# predictions
train_predict = model.predict(train_x)
test_predict = model.predict(test_x)

# invert predictions
# train_predict = scaler.inverse_transform(train_predict)
# train_true = scaler.inverse_transform([trainY])
# test_predict = scaler.inverse_transform(test_predict)
# test_true = scaler.inverse_transform([testY])
train_predict = train_predict
train_true = np.reshape(train_y,(1,-1))
test_predict = test_predict
test_true = np.reshape(test_y,(1,-1))

# calculate root mean squared error (RMSE)
trainScore = np.sqrt(mean_squared_error(train_true[0], train_predict[:, 0]))
train_score_percentage = np.sqrt(
    np.mean(
        np.square(((train_true[0] - train_predict[:, 0]) / train_true[0])),
        axis=0,
    )
)
test_score_percentage = np.sqrt(
    np.mean(
        np.square(((test_true[0] - test_predict[:, 0]) / test_true[0])),
        axis=0,
    )
)
train_score_percentage_output = (
    "Train RMSPE: %.4f RMSPE" % train_score_percentage
)
test_score_percentage_output = "Test RMSPE: %.4f RMSPE" % test_score_percentage
train_score_output = "Train Score: %.4f RMSE" % (trainScore)
testScore = np.sqrt(mean_squared_error(test_true[0], test_predict[:, 0]))
test_score_output = "Test Score: %.4f RMSE" % (testScore)
print(train_score_output)
print(test_score_output)
print(train_score_percentage_output)
print(test_score_percentage_output)
rmse_file = open(
    f"./Model3/{version}/info.md", "w"
)
rmse_file.write(
    train_score_output
    + "\n"
    + test_score_output
    + "\n"
    + train_score_percentage_output
    + "\n"
    + test_score_percentage_output
    + "\n"
    + to_string()
)
rmse_file.close()
# Out:
# 11/11 [==============================] - 0s 7ms/step
# 5/5 [==============================] - 0s 8ms/step
# Train Score: 0.0656 RMSE
# Test Score: 0.1745 RMSE
# Train RMSPE: inf RMSPE
# Test RMSPE: 2.0088 RMSPE
# C:\Users\Admin\AppData\Local\Temp\ipykernel_29100\3423561699.py:19: RuntimeWarning: divide by zero encountered in divide
#   np.square(((train_true[0] - train_predict[:, 0]) / train_true[0])),

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset[:,2]).reshape(-1,1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[TIME_STEP:len(train_predict)+TIME_STEP, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(dataset[:,2]).reshape(-1,1)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(TIME_STEP*2)+1:len(dataset)-1, :] = test_predict

true_values = (dataset)[:,2].reshape(-1,1)
print(true_values.shape)
print(trainPredictPlot.shape)
print(trainPredictPlot)
# plot baseline and predictions
plt.clf()
plt.figure(figsize=(10,6))
plt.rcParams.update({'font.size': 10})
plt.plot(true_values)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.savefig(f"Model3/{version}/predict.png")
plt.show()
# Out:
# (495, 1)
# (495, 1)
# [[       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [0.38599992]
#  [0.51143986]
#  [0.61329019]
#  [0.63742512]
#  [0.58988583]
#  [0.5938729 ]
#  [0.62323576]
#  [0.70791078]
#  [0.63622135]
#  [0.67736262]
#  [0.20483045]
#  [0.4630428 ]
#  [0.46914539]
#  [0.53327245]
#  [0.58398843]
#  [0.42085889]
#  [0.40069133]
#  [0.54787654]
#  [0.58637863]
#  [0.49278799]
#  [0.47373864]
#  [0.42688045]
#  [0.39218962]
#  [0.43698427]
#  [0.42349046]
#  [0.35702151]
#  [0.48212186]
#  [0.56742519]
#  [0.56583941]
#  [0.58619589]
#  [0.61810559]
#  [0.65217018]
#  [0.64351201]
#  [0.62588233]
#  [0.63551611]
#  [0.6812591 ]
#  [0.68514246]
#  [0.67218709]
#  [0.67888963]
#  [0.68665397]
#  [0.74583197]
#  [0.73989934]
#  [0.80854148]
#  [0.85576975]
#  [0.82772589]
#  [0.900581  ]
#  [0.87478578]
#  [0.79974747]
#  [0.69898772]
#  [0.6672141 ]
#  [0.79674643]
#  [0.84571779]
#  [0.46824604]
#  [0.37486953]
#  [0.24709043]
#  [0.53748888]
#  [0.5702706 ]
#  [0.6131013 ]
#  [0.59685469]
#  [0.61828119]
#  [0.63255203]
#  [0.60598087]
#  [0.68062592]
#  [0.64863294]
#  [0.71730369]
#  [0.69932383]
#  [0.65603119]
#  [0.67561132]
#  [0.72985792]
#  [0.74364531]
#  [0.77466428]
#  [0.65935987]
#  [0.45893443]
#  [0.25355673]
#  [0.53247201]
#  [0.59161198]
#  [0.52382046]
#  [0.51621372]
#  [0.37538576]
#  [0.36611918]
#  [0.53732359]
#  [0.51247287]
#  [0.48086044]
#  [0.48800814]
#  [0.56912106]
#  [0.65556985]
#  [0.65792412]
#  [0.61452127]
#  [0.64686608]
#  [0.66962892]
#  [0.80529571]
#  [0.82788175]
#  [0.82597554]
#  [0.92804134]
#  [0.8043257 ]
#  [0.93574965]
#  [1.059919  ]
#  [0.91876674]
#  [1.01292956]
#  [1.06794393]
#  [1.04276574]
#  [0.72249067]
#  [0.5279085 ]
#  [0.20703945]
#  [0.49383536]
#  [0.46238905]
#  [0.51136714]
#  [0.47404224]
#  [0.51574385]
#  [0.58314383]
#  [0.49191931]
#  [0.57253098]
#  [0.5946151 ]
#  [0.62070435]
#  [0.62009192]
#  [0.64375144]
#  [0.71475762]
#  [0.77631682]
#  [0.78137696]
#  [0.7278592 ]
#  [0.86725503]
#  [0.94121957]
#  [0.89328825]
#  [0.83827674]
#  [0.90495735]
#  [0.76192188]
#  [0.38025805]
#  [0.50729203]
#  [0.45857415]
#  [0.62997276]
#  [0.62785298]
#  [0.66017526]
#  [0.65545142]
#  [0.68231243]
#  [0.71284062]
#  [0.69299006]
#  [0.71443772]
#  [0.68776089]
#  [0.64414477]
#  [0.56603605]
#  [0.52090824]
#  [0.58291394]
#  [0.60167909]
#  [0.67244744]
#  [0.65368211]
#  [0.6867677 ]
#  [0.57063258]
#  [0.53099388]
#  [0.29041052]
#  [0.50866723]
#  [0.58426344]
#  [0.58684677]
#  [0.6167413 ]
#  [0.67911583]
#  [0.66932684]
#  [0.67497015]
#  [0.68603116]
#  [0.70412129]
#  [0.72121018]
#  [0.70183533]
#  [0.61647236]
#  [0.73900431]
#  [0.74436516]
#  [0.54394078]
#  [0.55408531]
#  [0.57049412]
#  [0.57418394]
#  [0.58114439]
#  [0.57979339]
#  [0.61505646]
#  [0.61613637]
#  [0.64219612]
#  [0.61668521]
#  [0.66236573]
#  [0.70508873]
#  [0.66823518]
#  [0.60619324]
#  [0.6009953 ]
#  [0.361292  ]
#  [0.37920538]
#  [0.19375566]
#  [0.49517041]
#  [0.50771403]
#  [0.58434737]
#  [0.61799657]
#  [0.6561811 ]
#  [0.58896285]
#  [0.63777483]
#  [0.52213585]
#  [0.48214132]
#  [0.37724012]
#  [0.46759719]
#  [0.51995981]
#  [0.50711817]
#  [0.5565123 ]
#  [0.55175745]
#  [0.61725736]
#  [0.63535726]
#  [0.16860679]
#  [0.45378864]
#  [0.5721404 ]
#  [0.55714977]
#  [0.53816628]
#  [0.48812386]
#  [0.54584914]
#  [0.64783567]
#  [0.52537131]
#  [0.51119184]
#  [0.53789282]
#  [0.59746742]
#  [0.6420781 ]
#  [0.64310586]
#  [0.616557  ]
#  [0.69358772]
#  [0.6769405 ]
#  [0.60467267]
#  [0.64646417]
#  [0.74575591]
#  [0.59342343]
#  [0.63250309]
#  [0.8893699 ]
#  [0.35785851]
#  [0.05452478]
#  [0.54534566]
#  [0.56502068]
#  [0.6079492 ]
#  [0.59174043]
#  [0.60673296]
#  [0.63130027]
#  [0.61621791]
#  [0.63832057]
#  [0.66031772]
#  [0.68659765]
#  [0.66174257]
#  [0.64994365]
#  [0.67543352]
#  [0.70898819]
#  [0.73916864]
#  [0.77632225]
#  [0.82313848]
#  [0.55131763]
#  [0.44089344]
#  [0.18761124]
#  [0.22028685]
#  [0.46151489]
#  [0.60115176]
#  [0.60168624]
#  [0.62028652]
#  [0.64689553]
#  [0.65805149]
#  [0.67166889]
#  [0.66734183]
#  [0.65713519]
#  [0.66712797]
#  [0.6791203 ]
#  [0.65283155]
#  [0.66845578]
#  [0.65173239]
#  [0.7090739 ]
#  [0.66347653]
#  [0.69434178]
#  [0.70150703]
#  [0.8138985 ]
#  [0.81141299]
#  [0.46074316]
#  [0.41507235]
#  [0.44525766]
#  [0.5774892 ]
#  [0.57881236]
#  [0.56574428]
#  [0.5876652 ]
#  [0.65603054]
#  [0.62459034]
#  [0.62392545]
#  [0.64626646]
#  [0.65386999]
#  [0.68825376]
#  [0.64301568]
#  [0.70754212]
#  [0.69598037]
#  [0.69677114]
#  [0.78426456]
#  [0.75382328]
#  [0.45334205]
#  [0.30709651]
#  [0.38779157]
#  [0.26389614]
#  [0.35913   ]
#  [0.2893014 ]
#  [0.27348071]
#  [0.16195834]
#  [0.34436098]
#  [0.60944915]
#  [0.57587177]
#  [0.55459821]
#  [0.59395981]
#  [0.58532363]
#  [0.6547913 ]
#  [0.66109025]
#  [0.6274125 ]
#  [0.54433781]
#  [0.47273824]
#  [0.53724837]
#  [0.58207268]
#  [0.61289728]
#  [0.60501665]
#  [0.63223088]
#  [0.63074058]
#  [0.64585364]
#  [0.58525157]
#  [0.61752361]
#  [0.68516845]
#  [0.69143474]
#  [0.68935573]
#  [0.65943778]
#  [0.65782285]
#  [0.58563048]
#  [0.16227795]
#  [0.54016113]
#  [0.60596579]
#  [0.64118475]
#  [0.65917838]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]
#  [       nan]]
